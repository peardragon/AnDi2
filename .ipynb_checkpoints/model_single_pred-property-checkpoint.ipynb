# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim

from utils.train import *
from utils.dataloader import *
from utils.resnet import resnet34_andi, resnet18_andi

# %%
import random
random.seed(42)

dataset_size = 200
num_epochs = 100

device = "cuda:0"

# %%
X_dict = {f"{feat}":[] for feat in ["feat"]}
y_dict = {f"{feat}":[] for feat in ["a"]}

for i in tqdm(range(dataset_size)):

    X = np.load(f"./ds_single/ds_{i}.npy", allow_pickle=True)
    y = np.load(f"./ds_single/ds_label_{i}.npy", allow_pickle=True)

    ### TO Tensor
    X = torch.Tensor(X).squeeze().unsqueeze(axis=2).type(torch.Tensor)
    
    y_a = torch.Tensor(y[:,2])
    
    X_dict["feat"].append(X)
    y_dict["a"].append(y_a)

train_dataloader_dict = {f"{feat}":[] for feat in ["a"]}
valid_dataloader_dict = {f"{feat}":[] for feat in ["a"]}

g = torch.Generator()
g.manual_seed(42)

for feat in ["a"]:
    X = X_dict["feat"]
    y = y_dict[feat]
    X = torch.cat(X)
    y = torch.cat(y)
    dataset = AnDiDataset(X, y)

    # ## split
    train_set, val_set = torch.utils.data.random_split(dataset, [0.7, 0.3], generator=g)
    
    train_loader = DataLoader(train_set, batch_size=256, collate_fn=collate_fn, generator=g, shuffle=True)
    
    valid_loader = DataLoader(val_set, batch_size=64, collate_fn=collate_fn, generator=g, shuffle=True)

    train_dataloader_dict[f"{feat}"] = train_loader
    valid_dataloader_dict[f"{feat}"] = valid_loader

del X, y
import gc
gc.collect()
# Out:
# 100%|██████████| 200/200 [03:05<00:00,  1.08it/s]
# 506

# %%
feat = "a"

model_name=f'predictor_{feat}_full_{dataset_size}'
# resnet34 / Scheduler / L1Loss 

# model = resnet34_andi(output_dim=1, output_num=1, problem_type="a")
model = resnet18_andi(output_dim=1, output_num=1, problem_type="a")

criterion = nn.L1Loss()

train_dataloader = train_dataloader_dict["a"]
valid_dataloader = valid_dataloader_dict["a"]



model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
                                                  criterion, 
                                                  # optimizer=optimizer, scheduler=scheduler,
                                                  num_epochs=num_epochs, device=device,  model_name=model_name,
                                                  tag=f"{feat}")
if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
    total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
else:
    np.save(f"./model/loss/{model_name}_{feat}.npy", np.array([total_train_loss, total_valid_loss]))

print(np.argmin(total_valid_loss), np.min(total_valid_loss))


plt.plot(total_train_loss)
plt.plot(total_valid_loss)
plt.title(f"{feat}")
plt.show()
# plt.savefig("a_loss.png")
# Out:
# Epoch 0 Loss:  0.8974774831390973
# Epoch 0 Eval Loss:  0.7562969221326233
# [EarlyStopping] (Update) Best Score: 0.75630
# Epoch 1 Loss:  0.14007583179969363
# Epoch 1 Eval Loss:  0.12691930434332938
# [EarlyStopping] (Update) Best Score: 0.12692
# Epoch 2 Loss:  0.12476356323036716
# Epoch 2 Eval Loss:  0.14002277151577594
# [EarlyStopping] (Patience) 1/10, Best: 0.12692, Current: 0.14002, Delta: 0.01310
# Epoch 3 Loss:  0.12138008333768986
# Epoch 3 Eval Loss:  0.12712859539101898
# [EarlyStopping] (Patience) 2/10, Best: 0.12692, Current: 0.12713, Delta: 0.00021
# Epoch 4 Loss:  0.1195427457823986
# Epoch 4 Eval Loss:  0.12165687738840032
# [EarlyStopping] (Update) Best Score: 0.12166
# Epoch 5 Loss:  0.11837043399903723
# Epoch 5 Eval Loss:  0.1355875057267375
# [EarlyStopping] (Patience) 1/10, Best: 0.12166, Current: 0.13559, Delta: 0.01393
# Epoch 6 Loss:  0.11752810572055183
# Epoch 6 Eval Loss:  0.12439197356563249
# [EarlyStopping] (Patience) 2/10, Best: 0.12166, Current: 0.12439, Delta: 0.00274
# Epoch 7 Loss:  0.11704700434172374
# Epoch 7 Eval Loss:  0.12057171844358854
# [EarlyStopping] (Update) Best Score: 0.12057
# Epoch 8 Loss:  0.11629276887559796
# Epoch 8 Eval Loss:  0.12169116083478579
# [EarlyStopping] (Patience) 1/10, Best: 0.12057, Current: 0.12169, Delta: 0.00112
# Epoch 9 Loss:  0.11583458492877775
# Epoch 9 Eval Loss:  0.22394329759368117
# [EarlyStopping] (Patience) 2/10, Best: 0.12057, Current: 0.22394, Delta: 0.10337
# Epoch 10 Loss:  0.11549800195284998
# Epoch 10 Eval Loss:  0.11827118955606834
# [EarlyStopping] (Update) Best Score: 0.11827
# Epoch 11 Loss:  0.11525922751361824
# Epoch 11 Eval Loss:  0.11867579465449346
# [EarlyStopping] (Patience) 1/10, Best: 0.11827, Current: 0.11868, Delta: 0.00040
# Epoch 12 Loss:  0.114755301399968
# Epoch 12 Eval Loss:  0.1214129565051698
# [EarlyStopping] (Patience) 2/10, Best: 0.11827, Current: 0.12141, Delta: 0.00314
# Epoch 13 Loss:  0.11445144031894139
# Epoch 13 Eval Loss:  0.13046492708601484
# [EarlyStopping] (Patience) 3/10, Best: 0.11827, Current: 0.13046, Delta: 0.01219
# Epoch 14 Loss:  0.11413009712834576
# Epoch 14 Eval Loss:  0.11780267830010636
# [EarlyStopping] (Update) Best Score: 0.11780
# Epoch 15 Loss:  0.11380585755100135
# Epoch 15 Eval Loss:  0.11593233489807639
# [EarlyStopping] (Update) Best Score: 0.11593
# Epoch 16 Loss:  0.1133962679792882
# Epoch 16 Eval Loss:  0.11515395598233827
# [EarlyStopping] (Update) Best Score: 0.11515
# Epoch 17 Loss:  0.11304129387690491
# Epoch 17 Eval Loss:  0.11264549139682449
# [EarlyStopping] (Update) Best Score: 0.11265
# Epoch 18 Loss:  0.11274334550631337
# Epoch 18 Eval Loss:  0.11245099766985675
# [EarlyStopping] (Update) Best Score: 0.11245
# Epoch 19 Loss:  0.11266756121871249
# Epoch 19 Eval Loss:  0.11351515341474416
# [EarlyStopping] (Patience) 1/10, Best: 0.11245, Current: 0.11352, Delta: 0.00106
# Epoch 20 Loss:  0.11156335087492068
# Epoch 20 Eval Loss:  0.11240300092071767
# [EarlyStopping] (Update) Best Score: 0.11240
# Epoch 21 Loss:  0.10764140280104212
# Epoch 21 Eval Loss:  0.10834307089456192
# [EarlyStopping] (Update) Best Score: 0.10834
# Epoch 22 Loss:  0.10688169271984847
# Epoch 22 Eval Loss:  0.10813529366107609
# [EarlyStopping] (Update) Best Score: 0.10814
# Epoch 23 Loss:  0.10651794829548385
# Epoch 23 Eval Loss:  0.10800441551441914
# [EarlyStopping] (Update) Best Score: 0.10800
# Epoch 24 Loss:  0.10628280073618146
# Epoch 24 Eval Loss:  0.10786112110899412
# [EarlyStopping] (Update) Best Score: 0.10786
# Epoch 25 Loss:  0.10610081170606891
# Epoch 25 Eval Loss:  0.10780633865642415
# [EarlyStopping] (Update) Best Score: 0.10781
# Epoch 26 Loss:  0.10594289249194173
# Epoch 26 Eval Loss:  0.10795496015481003
# [EarlyStopping] (Patience) 1/10, Best: 0.10781, Current: 0.10795, Delta: 0.00015
# Epoch 27 Loss:  0.1058047748715626
# Epoch 27 Eval Loss:  0.10805382677573774
# [EarlyStopping] (Patience) 2/10, Best: 0.10781, Current: 0.10805, Delta: 0.00025
# Epoch 28 Loss:  0.10570868328083657
# Epoch 28 Eval Loss:  0.10864880225770882
# [EarlyStopping] (Patience) 3/10, Best: 0.10781, Current: 0.10865, Delta: 0.00084
# Epoch 29 Loss:  0.10561661811234584
# Epoch 29 Eval Loss:  0.10771363604681018
# [EarlyStopping] (Update) Best Score: 0.10771
# Epoch 30 Loss:  0.10554531993032074
# Epoch 30 Eval Loss:  0.10812132938534492
# [EarlyStopping] (Patience) 1/10, Best: 0.10771, Current: 0.10812, Delta: 0.00041
# Epoch 31 Loss:  0.10547175386300833
# Epoch 31 Eval Loss:  0.10844318096319833
# [EarlyStopping] (Patience) 2/10, Best: 0.10771, Current: 0.10844, Delta: 0.00073
# Epoch 32 Loss:  0.10543801153348947
# Epoch 32 Eval Loss:  0.10814537179689025
# [EarlyStopping] (Patience) 3/10, Best: 0.10771, Current: 0.10815, Delta: 0.00043
# Epoch 33 Loss:  0.10540447553361751
# Epoch 33 Eval Loss:  0.10808948689190408
# [EarlyStopping] (Patience) 4/10, Best: 0.10771, Current: 0.10809, Delta: 0.00038
# Epoch 34 Loss:  0.10536113409361149
# Epoch 34 Eval Loss:  0.10859230038431428
# [EarlyStopping] (Patience) 5/10, Best: 0.10771, Current: 0.10859, Delta: 0.00088
# Epoch 35 Loss:  0.10536866505971337
# Epoch 35 Eval Loss:  0.10825737986314733
# [EarlyStopping] (Patience) 6/10, Best: 0.10771, Current: 0.10826, Delta: 0.00054
# Epoch 36 Loss:  0.10537248501648858
# Epoch 36 Eval Loss:  0.10962008287802863
# [EarlyStopping] (Patience) 7/10, Best: 0.10771, Current: 0.10962, Delta: 0.00191
# Epoch 37 Loss:  0.10538907179180641
# Epoch 37 Eval Loss:  0.10905885016702759
# [EarlyStopping] (Patience) 8/10, Best: 0.10771, Current: 0.10906, Delta: 0.00135
# Epoch 38 Loss:  0.10547753045758113
# Epoch 38 Eval Loss:  0.10908977655742798
# [EarlyStopping] (Patience) 9/10, Best: 0.10771, Current: 0.10909, Delta: 0.00138
# Epoch 39 Loss:  0.10547415738249072
# Epoch 39 Eval Loss:  0.10822725236370351
# [EarlyStopping] (Patience) 10/10, Best: 0.10771, Current: 0.10823, Delta: 0.00051
# [EarlyStop Triggered] Best Score: 0.10771
# 29 0.10771363604681018

# %%
X_dict = {f"{feat}":[] for feat in ["feat"]}
y_dict = {f"{feat}":[] for feat in ["k"]}

for i in tqdm(range(dataset_size)):

    X = np.load(f"./ds_single/ds_{i}.npy", allow_pickle=True)
    y = np.load(f"./ds_single/ds_label_{i}.npy", allow_pickle=True)

    ### TO Tensor
    X = torch.Tensor(X).squeeze().unsqueeze(axis=2).type(torch.Tensor)
    
    y = torch.Tensor(y[:,1])
    
    X_dict["feat"].append(X)
    y_dict["k"].append(y)

train_dataloader_dict = {f"{feat}":[] for feat in ["k"]}
valid_dataloader_dict = {f"{feat}":[] for feat in ["k"]}

g = torch.Generator()
g.manual_seed(42)

for feat in ["k"]:
    X = X_dict["feat"]
    y = y_dict[feat]
    X = torch.cat(X)
    y = torch.cat(y)
    dataset = AnDiDataset(X, y)

    # ## split
    train_set, val_set = torch.utils.data.random_split(dataset, [0.7, 0.3], generator=g)
    
    train_loader = DataLoader(train_set, batch_size=256, collate_fn=collate_fn, generator=g, shuffle=True)
    
    valid_loader = DataLoader(val_set, batch_size=64, collate_fn=collate_fn, generator=g, shuffle=True)

    train_dataloader_dict[f"{feat}"] = train_loader
    valid_dataloader_dict[f"{feat}"] = valid_loader

del X, y
import gc
gc.collect()
# Out:
# 100%|██████████| 200/200 [04:05<00:00,  1.23s/it]
# 4397

# %%
feat = "k"

model_name=f'predictor_{feat}_msle_full_{dataset_size}'
# resnet34 / Scheduler / MSELELoss

# model = resnet34_andi(output_dim=1, output_num=1, problem_type="k")
model = resnet18_andi(output_dim=1, output_num=1, problem_type="k")

def MSLELoss(outputs, labels):
    return torch.sqrt(torch.mean((torch.log(outputs+1)-torch.log(labels+1))**2))
criterion = MSLELoss

train_dataloader = train_dataloader_dict["k"]
valid_dataloader = valid_dataloader_dict["k"]


model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
                                                  criterion, 
                                                  # optimizer=optimizer, scheduler=scheduler,
                                                  num_epochs=num_epochs, device=device,  model_name=model_name,
                                                  tag=f"{feat}")
if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
    total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
else:
    np.save(f"./model/loss/{model_name}_{feat}.npy", np.array([total_train_loss, total_valid_loss]))

print(np.argmin(total_valid_loss), np.min(total_valid_loss))


plt.plot(total_train_loss)
plt.plot(total_valid_loss)
plt.title(f"{feat}")
plt.show()
# plt.savefig("k_loss.png")
# Out:
# Epoch 0 Loss:  0.5862742092447932
# Epoch 0 Eval Loss:  0.576303617513985
# [EarlyStopping] (Update) Best Score: 0.57630
# Epoch 1 Loss:  0.18567564760080546
# Epoch 1 Eval Loss:  0.1910313218809892
# [EarlyStopping] (Update) Best Score: 0.19103
# Epoch 2 Loss:  0.1766490736460555
# Epoch 2 Eval Loss:  0.21440493717153958
# [EarlyStopping] (Patience) 1/10, Best: 0.19103, Current: 0.21440, Delta: 0.02337
# Epoch 3 Loss:  0.17460533641609247
# Epoch 3 Eval Loss:  0.1822260293292422
# [EarlyStopping] (Update) Best Score: 0.18223
# Epoch 4 Loss:  0.1728420907441613
# Epoch 4 Eval Loss:  0.17137689819261231
# [EarlyStopping] (Update) Best Score: 0.17138
# Epoch 5 Loss:  0.1718627354586622
# Epoch 5 Eval Loss:  0.18334426912897941
# [EarlyStopping] (Patience) 1/10, Best: 0.17138, Current: 0.18334, Delta: 0.01197
# Epoch 6 Loss:  0.17105711755523068
# Epoch 6 Eval Loss:  0.17329136620800814
# [EarlyStopping] (Patience) 2/10, Best: 0.17138, Current: 0.17329, Delta: 0.00191
# Epoch 7 Loss:  0.1703705554733683
# Epoch 7 Eval Loss:  0.17102321481804922
# [EarlyStopping] (Update) Best Score: 0.17102
# Epoch 8 Loss:  0.16977207720281137
# Epoch 8 Eval Loss:  0.18484024120212197
# [EarlyStopping] (Patience) 1/10, Best: 0.17102, Current: 0.18484, Delta: 0.01382
# Epoch 9 Loss:  0.16927334194536145
# Epoch 9 Eval Loss:  0.18143616000797494
# [EarlyStopping] (Patience) 2/10, Best: 0.17102, Current: 0.18144, Delta: 0.01041
# Epoch 10 Loss:  0.16897382586760998
# Epoch 10 Eval Loss:  0.16990682696151516
# [EarlyStopping] (Update) Best Score: 0.16991
# Epoch 11 Loss:  0.16819117367487943
# Epoch 11 Eval Loss:  0.17230768883995767
# [EarlyStopping] (Patience) 1/10, Best: 0.16991, Current: 0.17231, Delta: 0.00240
# Epoch 12 Loss:  0.16795812621037232
# Epoch 12 Eval Loss:  0.16873424684740015
# [EarlyStopping] (Update) Best Score: 0.16873
# Epoch 13 Loss:  0.16736045965812255
# Epoch 13 Eval Loss:  0.16792030294358926
# [EarlyStopping] (Update) Best Score: 0.16792
# Epoch 14 Loss:  0.16700768184617365
# Epoch 14 Eval Loss:  0.169933975423567
# [EarlyStopping] (Patience) 1/10, Best: 0.16792, Current: 0.16993, Delta: 0.00201
# Epoch 15 Loss:  0.16630799084942988
# Epoch 15 Eval Loss:  0.1696503605674668
# [EarlyStopping] (Patience) 2/10, Best: 0.16792, Current: 0.16965, Delta: 0.00173
# Epoch 16 Loss:  0.16567381279324603
# Epoch 16 Eval Loss:  0.1685641408828391
# [EarlyStopping] (Patience) 3/10, Best: 0.16792, Current: 0.16856, Delta: 0.00064
# Epoch 17 Loss:  0.16497437057282238
# Epoch 17 Eval Loss:  0.17677741227148563
# [EarlyStopping] (Patience) 4/10, Best: 0.16792, Current: 0.17678, Delta: 0.00886
# Epoch 18 Loss:  0.16438542386357907
# Epoch 18 Eval Loss:  0.16674492985916803
# [EarlyStopping] (Update) Best Score: 0.16674
# Epoch 19 Loss:  0.163815116339216
# Epoch 19 Eval Loss:  0.19380529615000627
# [EarlyStopping] (Patience) 1/10, Best: 0.16674, Current: 0.19381, Delta: 0.02706
# Epoch 20 Loss:  0.16160836173520818
# Epoch 20 Eval Loss:  0.16469572774895336
# [EarlyStopping] (Update) Best Score: 0.16470
# Epoch 21 Loss:  0.1576149877694107
# Epoch 21 Eval Loss:  0.16170130921155457
# [EarlyStopping] (Update) Best Score: 0.16170
# Epoch 22 Loss:  0.1559135173515382
# Epoch 22 Eval Loss:  0.16139184127409475
# [EarlyStopping] (Update) Best Score: 0.16139
# Epoch 23 Loss:  0.15482291361313336
# Epoch 23 Eval Loss:  0.1614218524106951
# [EarlyStopping] (Patience) 1/10, Best: 0.16139, Current: 0.16142, Delta: 0.00003
# Epoch 24 Loss:  0.1539042860673374
# Epoch 24 Eval Loss:  0.16085947333193065
# [EarlyStopping] (Update) Best Score: 0.16086
# Epoch 25 Loss:  0.15301493220506246
# Epoch 25 Eval Loss:  0.16053035889690617
# [EarlyStopping] (Update) Best Score: 0.16053
# Epoch 26 Loss:  0.1521212074656583
# Epoch 26 Eval Loss:  0.16094244594388285
# [EarlyStopping] (Patience) 1/10, Best: 0.16053, Current: 0.16094, Delta: 0.00041
# Epoch 27 Loss:  0.15126918312666945
# Epoch 27 Eval Loss:  0.1603102136010202
# [EarlyStopping] (Update) Best Score: 0.16031
# Epoch 28 Loss:  0.15043510311390312
# Epoch 28 Eval Loss:  0.16057970516410092
# [EarlyStopping] (Patience) 1/10, Best: 0.16031, Current: 0.16058, Delta: 0.00027
# Epoch 29 Loss:  0.1496638165613574
# Epoch 29 Eval Loss:  0.16038627534266361
# [EarlyStopping] (Patience) 2/10, Best: 0.16031, Current: 0.16039, Delta: 0.00008
# Epoch 30 Loss:  0.14895599793350003
# Epoch 30 Eval Loss:  0.16148003312948062
# [EarlyStopping] (Patience) 3/10, Best: 0.16031, Current: 0.16148, Delta: 0.00117
# Epoch 31 Loss:  0.14834576542479072
# Epoch 31 Eval Loss:  0.16071463738904343
# [EarlyStopping] (Patience) 4/10, Best: 0.16031, Current: 0.16071, Delta: 0.00040
# Epoch 32 Loss:  0.14782799321963228
# Epoch 32 Eval Loss:  0.16141916498134332
# [EarlyStopping] (Patience) 5/10, Best: 0.16031, Current: 0.16142, Delta: 0.00111
# Epoch 33 Loss:  0.14742664618672902
# Epoch 33 Eval Loss:  0.16037298307630615
# [EarlyStopping] (Patience) 6/10, Best: 0.16031, Current: 0.16037, Delta: 0.00006
# Epoch 34 Loss:  0.14712803663372842
# Epoch 34 Eval Loss:  0.159784369076692
# [EarlyStopping] (Update) Best Score: 0.15978
# Epoch 35 Loss:  0.1468321192308335
# Epoch 35 Eval Loss:  0.15975254967303457
# [EarlyStopping] (Update) Best Score: 0.15975
# Epoch 36 Loss:  0.14661344207988347
# Epoch 36 Eval Loss:  0.16101272534145253
# [EarlyStopping] (Patience) 1/10, Best: 0.15975, Current: 0.16101, Delta: 0.00126
# Epoch 37 Loss:  0.14641216101945992
# Epoch 37 Eval Loss:  0.16001479111891972
# [EarlyStopping] (Patience) 2/10, Best: 0.15975, Current: 0.16001, Delta: 0.00026
# Epoch 38 Loss:  0.146345376982832
# Epoch 38 Eval Loss:  0.16610765704456001
# [EarlyStopping] (Patience) 3/10, Best: 0.15975, Current: 0.16611, Delta: 0.00636
# Epoch 39 Loss:  0.14626658242967921
# Epoch 39 Eval Loss:  0.16068628587635597
# [EarlyStopping] (Patience) 4/10, Best: 0.15975, Current: 0.16069, Delta: 0.00093
# Epoch 40 Loss:  0.14434295990313112
# Epoch 40 Eval Loss:  0.15976067828733387
# [EarlyStopping] (Patience) 5/10, Best: 0.15975, Current: 0.15976, Delta: 0.00001
# Epoch 41 Loss:  0.13933641389290466
# Epoch 41 Eval Loss:  0.15781543842437945
# [EarlyStopping] (Update) Best Score: 0.15782
# Epoch 42 Loss:  0.13723183930449
# Epoch 42 Eval Loss:  0.1574122244990882
# [EarlyStopping] (Update) Best Score: 0.15741
# Epoch 43 Loss:  0.1360991683041309
# Epoch 43 Eval Loss:  0.15717730750502504
# [EarlyStopping] (Update) Best Score: 0.15718
# Epoch 44 Loss:  0.135302256659499
# Epoch 44 Eval Loss:  0.1572762863179734
# [EarlyStopping] (Patience) 1/10, Best: 0.15718, Current: 0.15728, Delta: 0.00010
# Epoch 45 Loss:  0.13468483673060877
# Epoch 45 Eval Loss:  0.156899762743374
# [EarlyStopping] (Update) Best Score: 0.15690
# Epoch 46 Loss:  0.1341323662104433
# Epoch 46 Eval Loss:  0.1566977403598962
# [EarlyStopping] (Update) Best Score: 0.15670
# Epoch 47 Loss:  0.13370406327114204
# Epoch 47 Eval Loss:  0.1567252850369995
# [EarlyStopping] (Patience) 1/10, Best: 0.15670, Current: 0.15673, Delta: 0.00003
# Epoch 48 Loss:  0.13330334867918528
# Epoch 48 Eval Loss:  0.15656145436721944
# [EarlyStopping] (Update) Best Score: 0.15656
# Epoch 49 Loss:  0.13297778522014134
# Epoch 49 Eval Loss:  0.1563755952788301
# [EarlyStopping] (Update) Best Score: 0.15638
# Epoch 50 Loss:  0.13271772362493728
# Epoch 50 Eval Loss:  0.15655310908963394
# [EarlyStopping] (Patience) 1/10, Best: 0.15638, Current: 0.15655, Delta: 0.00018
# Epoch 51 Loss:  0.1324660798200907
# Epoch 51 Eval Loss:  0.15703370072251724
# [EarlyStopping] (Patience) 2/10, Best: 0.15638, Current: 0.15703, Delta: 0.00066
# Epoch 52 Loss:  0.13226766239196305
# Epoch 52 Eval Loss:  0.15654881953234626
# [EarlyStopping] (Patience) 3/10, Best: 0.15638, Current: 0.15655, Delta: 0.00017
# Epoch 53 Loss:  0.13214467822820555
# Epoch 53 Eval Loss:  0.15687843946425897
# [EarlyStopping] (Patience) 4/10, Best: 0.15638, Current: 0.15688, Delta: 0.00050
# Epoch 54 Loss:  0.13205096810863254
# Epoch 54 Eval Loss:  0.156736927952872
# [EarlyStopping] (Patience) 5/10, Best: 0.15638, Current: 0.15674, Delta: 0.00036
# Epoch 55 Loss:  0.13203696981480587
# Epoch 55 Eval Loss:  0.1563821897508328
# [EarlyStopping] (Patience) 6/10, Best: 0.15638, Current: 0.15638, Delta: 0.00001
# Epoch 56 Loss:  0.13200941097829116
# Epoch 56 Eval Loss:  0.1564474685487624
# [EarlyStopping] (Patience) 7/10, Best: 0.15638, Current: 0.15645, Delta: 0.00007
# Epoch 57 Loss:  0.13199201415794948
# Epoch 57 Eval Loss:  0.15703708841805503
# [EarlyStopping] (Patience) 8/10, Best: 0.15638, Current: 0.15704, Delta: 0.00066
# Epoch 58 Loss:  0.13207231590807592
# Epoch 58 Eval Loss:  0.15647650213539158
# [EarlyStopping] (Patience) 9/10, Best: 0.15638, Current: 0.15648, Delta: 0.00010
# Epoch 59 Loss:  0.132150182327374
# Epoch 59 Eval Loss:  0.1566256965322876
# [EarlyStopping] (Patience) 10/10, Best: 0.15638, Current: 0.15663, Delta: 0.00025
# [EarlyStop Triggered] Best Score: 0.15638
# 49 0.1563755952788301

# %%
X_dict = {f"{feat}":[] for feat in ["feat"]}
y_dict = {f"{feat}":[] for feat in ["s"]}

for i in tqdm(range(dataset_size)):

    X = np.load(f"./ds_single/ds_{i}.npy", allow_pickle=True)
    y = np.load(f"./ds_single/ds_label_{i}.npy", allow_pickle=True)

    ### TO Tensor
    X = torch.Tensor(X).squeeze().unsqueeze(axis=2).type(torch.Tensor)
    
    y = torch.Tensor(y[:,3]).to(torch.long)
    
    X_dict["feat"].append(X)
    y_dict["s"].append(y)    

train_dataloader_dict = {f"{feat}":[] for feat in ["s"]}
valid_dataloader_dict = {f"{feat}":[] for feat in ["s"]}

g = torch.Generator()
g.manual_seed(42)

for feat in ["s"]:
    X = X_dict["feat"]
    y = y_dict[feat]
    X = torch.cat(X)
    y = torch.cat(y)
    dataset = AnDiDataset(X, y)

    # split
    train_set, val_set = torch.utils.data.random_split(dataset, [0.7, 0.3], generator=g)
    
    train_loader = DataLoader(train_set, batch_size=256, collate_fn=collate_fn, generator=g, shuffle=True)
    
    valid_loader = DataLoader(val_set, batch_size=64, collate_fn=collate_fn, generator=g, shuffle=True)

    train_dataloader_dict[f"{feat}"] = train_loader
    valid_dataloader_dict[f"{feat}"] = valid_loader

del X, y
import gc
gc.collect()
# Out:
# 100%|██████████| 200/200 [00:26<00:00,  7.51it/s]
# 682

# %%
feat = "s"

model_name=f'predictor_{feat}_full_{dataset_size}'
# resnet34 / Scheduler / FocalLoss()

# model = resnet34_andi(output_dim=4, output_num=1, problem_type="s
model = resnet18_andi(output_dim=4, output_num=1, problem_type="s")

criterion = nn.CrossEntropyLoss()


train_dataloader = train_dataloader_dict["s"]
valid_dataloader = valid_dataloader_dict["s"]



model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
                                                  criterion,  clf=True,
                                                  # optimizer=optimizer, scheduler=scheduler,
                                                  num_epochs=num_epochs, device=device,  model_name=model_name,
                                                  tag=f"{feat}")
if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
    total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
else:
    np.save(f"./model/loss/{model_name}_{feat}.npy", np.array([total_train_loss, total_valid_loss]))

print(np.argmin(total_valid_loss), np.min(total_valid_loss))


plt.plot(total_train_loss)
plt.plot(total_valid_loss)
plt.title(f"{feat}")
plt.show()
# plt.savefig("s_loss.png")
# Out:
# Epoch 0 Loss:  1.4745553133791345
# Epoch 0 Eval ACC:  0.686506076057096
# Epoch 0 Eval Loss:  1.100942729256767
# [EarlyStopping] (Update) Best Score: 1.10094
# Epoch 1 Loss:  0.23038732457539204
# Epoch 1 Eval ACC:  0.9196586661529087
# Epoch 1 Eval Loss:  0.22272634745805983
# [EarlyStopping] (Update) Best Score: 0.22273
# Epoch 2 Loss:  0.20743966827340363
# Epoch 2 Eval ACC:  0.9185517592749296
# Epoch 2 Eval Loss:  0.21672637636368908
# [EarlyStopping] (Update) Best Score: 0.21673
# Epoch 3 Loss:  0.20114486295634698
# Epoch 3 Eval ACC:  0.9207132103701929
# Epoch 3 Eval Loss:  0.21569301546588357
# [EarlyStopping] (Update) Best Score: 0.21569
# Epoch 4 Loss:  0.19734999339690024
# Epoch 4 Eval ACC:  0.9178489507362367
# Epoch 4 Eval Loss:  0.226341082896401
# [EarlyStopping] (Patience) 1/10, Best: 0.21569, Current: 0.22634, Delta: 0.01065
# Epoch 5 Loss:  0.1947103425661381
# Epoch 5 Eval ACC:  0.9207379555938124
# Epoch 5 Eval Loss:  0.21352067154709806
# [EarlyStopping] (Update) Best Score: 0.21352
# Epoch 6 Loss:  0.19251166201621162
# Epoch 6 Eval ACC:  0.9222014588193082
# Epoch 6 Eval Loss:  0.2094635785661246
# [EarlyStopping] (Update) Best Score: 0.20946
# Epoch 7 Loss:  0.19069515860429065
# Epoch 7 Eval ACC:  0.9194090045217478
# Epoch 7 Eval Loss:  0.2165055420073816
# [EarlyStopping] (Patience) 1/10, Best: 0.20946, Current: 0.21651, Delta: 0.00704
# Epoch 8 Loss:  0.18951058725158168
# Epoch 8 Eval ACC:  0.918673275998061
# Epoch 8 Eval Loss:  0.22515422151696207
# [EarlyStopping] (Patience) 2/10, Best: 0.20946, Current: 0.22515, Delta: 0.01569
# Epoch 9 Loss:  0.18800001762113494
# Epoch 9 Eval ACC:  0.9273798387406802
# Epoch 9 Eval Loss:  0.1935277813083292
# [EarlyStopping] (Update) Best Score: 0.19353
# Epoch 10 Loss:  0.18724840093114548
# Epoch 10 Eval ACC:  0.9292288813877475
# Epoch 10 Eval Loss:  0.18861009605711201
# [EarlyStopping] (Update) Best Score: 0.18861
# Epoch 11 Loss:  0.1857742835288654
# Epoch 11 Eval ACC:  0.9294719148340104
# Epoch 11 Eval Loss:  0.1892750253032919
# [EarlyStopping] (Patience) 1/10, Best: 0.18861, Current: 0.18928, Delta: 0.00066
# Epoch 12 Loss:  0.18403363646499177
# Epoch 12 Eval ACC:  0.9296787142028304
# Epoch 12 Eval Loss:  0.18824260356696812
# [EarlyStopping] (Update) Best Score: 0.18824
# Epoch 13 Loss:  0.18329224712146508
# Epoch 13 Eval ACC:  0.9274578303829809
# Epoch 13 Eval Loss:  0.19548950869923956
# [EarlyStopping] (Patience) 1/10, Best: 0.18824, Current: 0.19549, Delta: 0.00725
# Epoch 14 Loss:  0.18183971069304913
# Epoch 14 Eval ACC:  0.9283800318418003
# Epoch 14 Eval Loss:  0.19123518396988004
# [EarlyStopping] (Patience) 2/10, Best: 0.18824, Current: 0.19124, Delta: 0.00299
# Epoch 15 Loss:  0.18055600936206664
# Epoch 15 Eval ACC:  0.9290899104443845
# Epoch 15 Eval Loss:  0.18911290625735927
# [EarlyStopping] (Patience) 3/10, Best: 0.18824, Current: 0.18911, Delta: 0.00087
# Epoch 16 Loss:  0.1812515100382502
# Epoch 16 Eval ACC:  0.9312677110623964
# Epoch 16 Eval Loss:  0.18393520326674076
# [EarlyStopping] (Update) Best Score: 0.18394
# Epoch 17 Loss:  0.17819900924209225
# Epoch 17 Eval ACC:  0.929770183154424
# Epoch 17 Eval Loss:  0.18826732316755823
# [EarlyStopping] (Patience) 1/10, Best: 0.18394, Current: 0.18827, Delta: 0.00433
# Epoch 18 Loss:  0.1763444240539782
# Epoch 18 Eval ACC:  0.926827269059677
# Epoch 18 Eval Loss:  0.1972690765584473
# [EarlyStopping] (Patience) 2/10, Best: 0.18394, Current: 0.19727, Delta: 0.01333
# Epoch 19 Loss:  0.1763990130639402
# Epoch 19 Eval ACC:  0.9290324661752678
# Epoch 19 Eval Loss:  0.19101668996766563
# [EarlyStopping] (Patience) 3/10, Best: 0.18394, Current: 0.19102, Delta: 0.00708
# Epoch 20 Loss:  0.17626439858233928
# Epoch 20 Eval ACC:  0.9304113495735646
# Epoch 20 Eval Loss:  0.18668956136008402
# [EarlyStopping] (Patience) 4/10, Best: 0.18394, Current: 0.18669, Delta: 0.00275
# Epoch 21 Loss:  0.15956030234477037
# Epoch 21 Eval ACC:  0.9356288357858354
# Epoch 21 Eval Loss:  0.17272456185033475
# [EarlyStopping] (Update) Best Score: 0.17272
# Epoch 22 Loss:  0.15566808780119867
# Epoch 22 Eval ACC:  0.9362605018066222
# Epoch 22 Eval Loss:  0.17211312391485997
# [EarlyStopping] (Update) Best Score: 0.17211
# Epoch 23 Loss:  0.15326693894279914
# Epoch 23 Eval ACC:  0.9368930515853956
# Epoch 23 Eval Loss:  0.1720370195856437
# [EarlyStopping] (Update) Best Score: 0.17204
# Epoch 24 Loss:  0.1512754624185288
# Epoch 24 Eval ACC:  0.936893935343382
# Epoch 24 Eval Loss:  0.17219350924935717
# [EarlyStopping] (Patience) 1/10, Best: 0.17204, Current: 0.17219, Delta: 0.00016
# Epoch 25 Loss:  0.14943807307986023
# Epoch 25 Eval ACC:  0.9373479660089004
# Epoch 25 Eval Loss:  0.17249498593495285
# [EarlyStopping] (Patience) 2/10, Best: 0.17204, Current: 0.17249, Delta: 0.00046
# Epoch 26 Loss:  0.14756809632887294
# Epoch 26 Eval ACC:  0.9377058879933966
# Epoch 26 Eval Loss:  0.1722797243348954
# [EarlyStopping] (Patience) 3/10, Best: 0.17204, Current: 0.17228, Delta: 0.00024
# Epoch 27 Loss:  0.14572027393636106
# Epoch 27 Eval ACC:  0.9373325002441382
# Epoch 27 Eval Loss:  0.17267610916192522
# [EarlyStopping] (Patience) 4/10, Best: 0.17204, Current: 0.17268, Delta: 0.00064
# Epoch 28 Loss:  0.143877426485099
# Epoch 28 Eval ACC:  0.9373658621081251
# Epoch 28 Eval Loss:  0.17442537798836355
# [EarlyStopping] (Patience) 5/10, Best: 0.17204, Current: 0.17443, Delta: 0.00239
# Epoch 29 Loss:  0.1422060171528078
# Epoch 29 Eval ACC:  0.9377109696018184
# Epoch 29 Eval Loss:  0.17425708274167032
# [EarlyStopping] (Patience) 6/10, Best: 0.17204, Current: 0.17426, Delta: 0.00222
# Epoch 30 Loss:  0.14057170887073914
# Epoch 30 Eval ACC:  0.9365209894731168
# Epoch 30 Eval Loss:  0.18288361613255522
# [EarlyStopping] (Patience) 7/10, Best: 0.17204, Current: 0.18288, Delta: 0.01085
# Epoch 31 Loss:  0.1392379387283596
# Epoch 31 Eval ACC:  0.9382469688205763
# Epoch 31 Eval Loss:  0.1750490208673302
# [EarlyStopping] (Patience) 8/10, Best: 0.17204, Current: 0.17505, Delta: 0.00301
# Epoch 32 Loss:  0.13774687676405303
# Epoch 32 Eval ACC:  0.9374566682412289
# Epoch 32 Eval Loss:  0.18056403543245755
# [EarlyStopping] (Patience) 9/10, Best: 0.17204, Current: 0.18056, Delta: 0.00853
# Epoch 33 Loss:  0.13652165482345263
# Epoch 33 Eval ACC:  0.9370165567639964
# Epoch 33 Eval Loss:  0.18031250493399822
# [EarlyStopping] (Patience) 10/10, Best: 0.17204, Current: 0.18031, Delta: 0.00828
# [EarlyStop Triggered] Best Score: 0.17204
# 23 0.1720370195856437

# %%
corr = []
model.to(device)
for x,y in valid_dataloader:
    z = model(x.to(device))
    corr.append(torch.round(torch.argmax(z, dim=1))==y.to(device))
corr = torch.cat(corr)
print(torch.sum(corr)/len(corr))
# Out:
# tensor(0.9370, device='cuda:0')

# %%
# %run ./model_single_pred-property-34.ipynb
# Out:
# 100%|██████████| 200/200 [04:20<00:00,  1.30s/it]
# Epoch 0 Loss:  0.5481112229686519
# Epoch 0 Eval Loss:  0.4108136139163331
# [EarlyStopping] (Update) Best Score: 0.41081
# Epoch 1 Loss:  0.14031625804062636
# Epoch 1 Eval Loss:  0.12983099505254933
# [EarlyStopping] (Update) Best Score: 0.12983
# Epoch 2 Loss:  0.12574800382626844
# Epoch 2 Eval Loss:  0.13263620430334003
# [EarlyStopping] (Patience) 1/10, Best: 0.12983, Current: 0.13264, Delta: 0.00281
# Epoch 3 Loss:  0.13084867299011219
# Epoch 3 Eval Loss:  0.12295766650340476
# [EarlyStopping] (Update) Best Score: 0.12296
# Epoch 4 Loss:  0.1204786295174278
# Epoch 4 Eval Loss:  0.12199513841300258
# [EarlyStopping] (Update) Best Score: 0.12200
# Epoch 5 Loss:  0.11868446824555917
# Epoch 5 Eval Loss:  0.12414304750375377
# [EarlyStopping] (Patience) 1/10, Best: 0.12200, Current: 0.12414, Delta: 0.00215
# Epoch 6 Loss:  0.11768185932218303
# Epoch 6 Eval Loss:  0.12195636687207395
# [EarlyStopping] (Update) Best Score: 0.12196
# Epoch 7 Loss:  0.11689690521447722
# Epoch 7 Eval Loss:  0.1209000766084941
# [EarlyStopping] (Update) Best Score: 0.12090
# Epoch 8 Loss:  0.1164892958004412
# Epoch 8 Eval Loss:  0.11730991424548491
# [EarlyStopping] (Update) Best Score: 0.11731
# Epoch 9 Loss:  0.11596127830721366
# Epoch 9 Eval Loss:  0.11888421722165961
# [EarlyStopping] (Patience) 1/10, Best: 0.11731, Current: 0.11888, Delta: 0.00157
# Epoch 10 Loss:  0.11533382463191232
# Epoch 10 Eval Loss:  0.12596261665776862
# [EarlyStopping] (Patience) 2/10, Best: 0.11731, Current: 0.12596, Delta: 0.00865
# Epoch 11 Loss:  0.11493439348653388
# Epoch 11 Eval Loss:  0.11463908725651702
# [EarlyStopping] (Update) Best Score: 0.11464
# Epoch 12 Loss:  0.11464459785930883
# Epoch 12 Eval Loss:  0.11619869274923361
# [EarlyStopping] (Patience) 1/10, Best: 0.11464, Current: 0.11620, Delta: 0.00156
# Epoch 13 Loss:  0.11431170935022991
# Epoch 13 Eval Loss:  0.11667787253396693
# [EarlyStopping] (Patience) 2/10, Best: 0.11464, Current: 0.11668, Delta: 0.00204
# Epoch 14 Loss:  0.11395364942989654
# Epoch 14 Eval Loss:  0.11638907536538112
# [EarlyStopping] (Patience) 3/10, Best: 0.11464, Current: 0.11639, Delta: 0.00175
# Epoch 15 Loss:  0.1137940217911729
# Epoch 15 Eval Loss:  0.12192334015709305
# [EarlyStopping] (Patience) 4/10, Best: 0.11464, Current: 0.12192, Delta: 0.00728
# Epoch 16 Loss:  0.11357102311221848
# Epoch 16 Eval Loss:  0.12478557076861461
# [EarlyStopping] (Patience) 5/10, Best: 0.11464, Current: 0.12479, Delta: 0.01015
# Epoch 17 Loss:  0.11337024624862506
# Epoch 17 Eval Loss:  0.11608937363476633
# [EarlyStopping] (Patience) 6/10, Best: 0.11464, Current: 0.11609, Delta: 0.00145
# Epoch 18 Loss:  0.11293278329311694
# Epoch 18 Eval Loss:  0.5297975027726042
# [EarlyStopping] (Patience) 7/10, Best: 0.11464, Current: 0.52980, Delta: 0.41516
# Epoch 19 Loss:  0.11280108225130622
# Epoch 19 Eval Loss:  0.1140369422998954
# [EarlyStopping] (Update) Best Score: 0.11404
# Epoch 20 Loss:  0.11301368639254533
# Epoch 20 Eval Loss:  0.11376439703295535
# [EarlyStopping] (Update) Best Score: 0.11376
# Epoch 21 Loss:  0.10798990110778546
# Epoch 21 Eval Loss:  0.1084426095794882
# [EarlyStopping] (Update) Best Score: 0.10844
# Epoch 22 Loss:  0.10718100242948471
# Epoch 22 Eval Loss:  0.10814491220939429
# [EarlyStopping] (Update) Best Score: 0.10814
# Epoch 23 Loss:  0.10679519898279596
# Epoch 23 Eval Loss:  0.1081152387460417
# [EarlyStopping] (Update) Best Score: 0.10812
# Epoch 24 Loss:  0.10654993947903646
# Epoch 24 Eval Loss:  0.1079412925709201
# [EarlyStopping] (Update) Best Score: 0.10794
# Epoch 25 Loss:  0.10635007801590983
# Epoch 25 Eval Loss:  0.10854092668119576
# [EarlyStopping] (Patience) 1/10, Best: 0.10794, Current: 0.10854, Delta: 0.00060
# Epoch 26 Loss:  0.1062132881374307
# Epoch 26 Eval Loss:  0.10772180562539634
# [EarlyStopping] (Update) Best Score: 0.10772
# Epoch 27 Loss:  0.1060744294609654
# Epoch 27 Eval Loss:  0.10840072283899164
# [EarlyStopping] (Patience) 1/10, Best: 0.10772, Current: 0.10840, Delta: 0.00068
# Epoch 28 Loss:  0.10597365179240961
# Epoch 28 Eval Loss:  0.10816067870636208
# [EarlyStopping] (Patience) 2/10, Best: 0.10772, Current: 0.10816, Delta: 0.00044
# Epoch 29 Loss:  0.10587573730843583
# Epoch 29 Eval Loss:  0.10783210061753389
# [EarlyStopping] (Patience) 3/10, Best: 0.10772, Current: 0.10783, Delta: 0.00011
# Epoch 30 Loss:  0.10582584373729871
# Epoch 30 Eval Loss:  0.1082651296839388
# [EarlyStopping] (Patience) 4/10, Best: 0.10772, Current: 0.10827, Delta: 0.00054
# Epoch 31 Loss:  0.10573621272608047
# Epoch 31 Eval Loss:  0.10904594553097678
# [EarlyStopping] (Patience) 5/10, Best: 0.10772, Current: 0.10905, Delta: 0.00132
# Epoch 32 Loss:  0.10570283383586146
# Epoch 32 Eval Loss:  0.10860509980810808
# [EarlyStopping] (Patience) 6/10, Best: 0.10772, Current: 0.10861, Delta: 0.00088
# Epoch 33 Loss:  0.10571476803712268
# Epoch 33 Eval Loss:  0.10950452536027419
# [EarlyStopping] (Patience) 7/10, Best: 0.10772, Current: 0.10950, Delta: 0.00178
# Epoch 34 Loss:  0.10591529531168418
# Epoch 34 Eval Loss:  0.1089023622236291
# [EarlyStopping] (Patience) 8/10, Best: 0.10772, Current: 0.10890, Delta: 0.00118
# Epoch 35 Loss:  0.10617604428245687
# Epoch 35 Eval Loss:  0.1080474904327824
# [EarlyStopping] (Patience) 9/10, Best: 0.10772, Current: 0.10805, Delta: 0.00033
# Epoch 36 Loss:  0.10587978211944955
# Epoch 36 Eval Loss:  0.11031092021474354
# [EarlyStopping] (Patience) 10/10, Best: 0.10772, Current: 0.11031, Delta: 0.00259
# [EarlyStop Triggered] Best Score: 0.10772
# 26 0.10772180562539634
# 100%|██████████| 200/200 [04:19<00:00,  1.30s/it]
# Epoch 0 Loss:  0.3315401908374881
# Epoch 0 Eval Loss:  0.3082038565016924
# [EarlyStopping] (Update) Best Score: 0.30820
# Epoch 1 Loss:  0.18805093455518068
# Epoch 1 Eval Loss:  0.28769721557902167
# [EarlyStopping] (Update) Best Score: 0.28770
# Epoch 2 Loss:  0.1772405030529576
# Epoch 2 Eval Loss:  0.1979686798983562
# [EarlyStopping] (Update) Best Score: 0.19797
# Epoch 3 Loss:  0.1752448852538395
# Epoch 3 Eval Loss:  0.18664453853917246
# [EarlyStopping] (Update) Best Score: 0.18664
# Epoch 4 Loss:  0.17414627486712836
# Epoch 4 Eval Loss:  0.1726117689883678
# [EarlyStopping] (Update) Best Score: 0.17261
# Epoch 5 Loss:  0.17231760133978363
# Epoch 5 Eval Loss:  0.1907411790009696
# [EarlyStopping] (Patience) 1/10, Best: 0.17261, Current: 0.19074, Delta: 0.01813
# Epoch 6 Loss:  0.17129364254599386
# Epoch 6 Eval Loss:  0.18097279013761158
# [EarlyStopping] (Patience) 2/10, Best: 0.17261, Current: 0.18097, Delta: 0.00836
# Epoch 7 Loss:  0.17054132202193817
# Epoch 7 Eval Loss:  0.18194507709979638
# [EarlyStopping] (Patience) 3/10, Best: 0.17261, Current: 0.18195, Delta: 0.00933
# Epoch 8 Loss:  0.16985274086488128
# Epoch 8 Eval Loss:  0.1748668836437274
# [EarlyStopping] (Patience) 4/10, Best: 0.17261, Current: 0.17487, Delta: 0.00226
# Epoch 9 Loss:  0.16928787832465556
# Epoch 9 Eval Loss:  0.49075445325213696
# [EarlyStopping] (Patience) 5/10, Best: 0.17261, Current: 0.49075, Delta: 0.31814
# Epoch 10 Loss:  0.16877505506462484
# Epoch 10 Eval Loss:  0.1767739382805971
# [EarlyStopping] (Patience) 6/10, Best: 0.17261, Current: 0.17677, Delta: 0.00416
# Epoch 11 Loss:  0.1682765742822302
# Epoch 11 Eval Loss:  0.1699614593881466
# [EarlyStopping] (Update) Best Score: 0.16996
# Epoch 12 Loss:  0.16800762774197825
# Epoch 12 Eval Loss:  0.1728140425945068
# [EarlyStopping] (Patience) 1/10, Best: 0.16996, Current: 0.17281, Delta: 0.00285
# Epoch 13 Loss:  0.16713671149526055
# Epoch 13 Eval Loss:  0.18467819886468953
# [EarlyStopping] (Patience) 2/10, Best: 0.16996, Current: 0.18468, Delta: 0.01472
# Epoch 14 Loss:  0.1664987254351249
# Epoch 14 Eval Loss:  0.17013246077520103
# [EarlyStopping] (Patience) 3/10, Best: 0.16996, Current: 0.17013, Delta: 0.00017
# Epoch 15 Loss:  0.16578994972696623
# Epoch 15 Eval Loss:  0.1723145086016053
# [EarlyStopping] (Patience) 4/10, Best: 0.16996, Current: 0.17231, Delta: 0.00235
# Epoch 16 Loss:  0.16515295853678583
# Epoch 16 Eval Loss:  0.1702730935507572
# [EarlyStopping] (Patience) 5/10, Best: 0.16996, Current: 0.17027, Delta: 0.00031
# Epoch 17 Loss:  0.16448555067531956
# Epoch 17 Eval Loss:  0.1694073289877424
# [EarlyStopping] (Update) Best Score: 0.16941
# Epoch 18 Loss:  0.16375046509946145
# Epoch 18 Eval Loss:  0.16529803671421817
# [EarlyStopping] (Update) Best Score: 0.16530
# Epoch 19 Loss:  0.1631127462291669
# Epoch 19 Eval Loss:  0.17295750780771313
# [EarlyStopping] (Patience) 1/10, Best: 0.16530, Current: 0.17296, Delta: 0.00766
# Epoch 20 Loss:  0.16206051122682355
# Epoch 20 Eval Loss:  0.1655402668684338
# [EarlyStopping] (Patience) 2/10, Best: 0.16530, Current: 0.16554, Delta: 0.00024
# Epoch 21 Loss:  0.15638672772408652
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /tmp/ipykernel_434594/2150086216.py:17
#      13 train_dataloader = train_dataloader_dict["k"]
#      14 valid_dataloader = valid_dataloader_dict["k"]
# ---> 17 model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
#      18                                                   criterion,
#      19                                                   # optimizer=optimizer, scheduler=scheduler,
#      20                                                   num_epochs=num_epochs, device=device,  model_name=model_name,
#      21                                                   tag=f"{feat}")
#      22 if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
#      23     total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
#
# File ~/andi2/utils/train.py:74, in train(model, train_dataloader, valid_dataloader, criterion, num_epochs, clf, optimizer, scheduler, device, model_name, tag)
#      71 labels = labels.to(device)
#      72 inputs = data.to(device)
# ---> 74 outputs = model(inputs)
#      75 loss = criterion(outputs, labels)
#      76 valid_loss.append(loss.item())
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/andi2/utils/resnet.py:456, in ResNetAnDi.forward(self, x)
#     455 def forward(self, x: Tensor) -> Tensor:
# --> 456     return self._forward_impl(x)
#
# File ~/andi2/utils/resnet.py:440, in ResNetAnDi._forward_impl(self, x)
#     437 x = self.relu(x)
#     438 x = self.maxpool(x)
# --> 440 x = self.layer1(x)
#     441 x = self.layer2(x)
#     442 x = self.layer3(x)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/andi2/utils/resnet.py:98, in BasicBlock.forward(self, x)
#      95 identity = x
#      97 out = self.conv1(x)
# ---> 98 out = self.bn1(out)
#      99 out = self.relu(out)
#     101 out = self.conv2(out)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1507, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1504             tracing_state.pop_scope()
#    1505     return result
# -> 1507 def _wrapped_call_impl(self, *args, **kwargs):
#    1508     if self._compiled_call_impl is not None:
#    1509         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 get_ipython().run_line_magic('run', './model_single_pred-property-34.ipynb')
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/IPython/core/magics/execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/IPython/core/interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File /tmp/ipykernel_434594/2150086216.py:17
#      13 train_dataloader = train_dataloader_dict["k"]
#      14 valid_dataloader = valid_dataloader_dict["k"]
# ---> 17 model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
#      18                                                   criterion,
#      19                                                   # optimizer=optimizer, scheduler=scheduler,
#      20                                                   num_epochs=num_epochs, device=device,  model_name=model_name,
#      21                                                   tag=f"{feat}")
#      22 if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
#      23     total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
#
# File ~/andi2/utils/train.py:74, in train(model, train_dataloader, valid_dataloader, criterion, num_epochs, clf, optimizer, scheduler, device, model_name, tag)
#      71 labels = labels.to(device)
#      72 inputs = data.to(device)
# ---> 74 outputs = model(inputs)
#      75 loss = criterion(outputs, labels)
#      76 valid_loss.append(loss.item())
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/andi2/utils/resnet.py:456, in ResNetAnDi.forward(self, x)
#     455 def forward(self, x: Tensor) -> Tensor:
# --> 456     return self._forward_impl(x)
#
# File ~/andi2/utils/resnet.py:440, in ResNetAnDi._forward_impl(self, x)
#     437 x = self.relu(x)
#     438 x = self.maxpool(x)
# --> 440 x = self.layer1(x)
#     441 x = self.layer2(x)
#     442 x = self.layer3(x)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/andi2/utils/resnet.py:98, in BasicBlock.forward(self, x)
#      95 identity = x
#      97 out = self.conv1(x)
# ---> 98 out = self.bn1(out)
#      99 out = self.relu(out)
#     101 out = self.conv2(out)
#
# File ~/miniconda3/envs/andi2/lib/python3.10/site-packages/torch/nn/modules/module.py:1507, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1504             tracing_state.pop_scope()
#    1505     return result
# -> 1507 def _wrapped_call_impl(self, *args, **kwargs):
#    1508     if self._compiled_call_impl is not None:
#    1509         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:
