# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim

from utils.train import *
from utils.dataloader import *
from utils.resnet import resnet34_andi, resnet18_andi

# %%
import random
random.seed(42)

dataset_size = 1 # Challenge 150 for classifier, 200 for cp step predictor
num_epochs = 100

device = "cuda"

# %% [markdown]
# #

# %%
X_dict = {f"{feat}":[] for feat in ["feat"]}
y_dict = {f"{feat}":[] for feat in ["cp", "pad"]}

for i in tqdm(range(dataset_size)):

    X = np.load(f"./ds_single/ds_{i}.npy", allow_pickle=True)
    y = np.load(f"./ds_single/ds_label_{i}.npy", allow_pickle=True)
    y_pad = np.load(f"./ds_single/ds_pad_{i}.npy", allow_pickle=True)
    ### TO Tensor
    X = torch.Tensor(X).squeeze().unsqueeze(axis=2).type(torch.Tensor)
    
    y_cp = torch.Tensor(y[:,4])
    y_pad = torch.Tensor(y_pad)
    arg = torch.argwhere(y_cp<200)
    
    X_dict["feat"].append(X[arg].squeeze(dim=1))
    y_dict["cp"].append(y_cp[arg].squeeze(dim=1))
    y_dict["pad"].append(y_pad[arg].squeeze(dim=1))
    
train_dataloader_dict = {f"{feat}":[] for feat in ["cp"]}
valid_dataloader_dict = {f"{feat}":[] for feat in ["cp"]}

g = torch.Generator()
g.manual_seed(42)

for feat in ["cp"]:
    X = X_dict["feat"]
    y = y_dict[feat]
    y_pad = y_dict["pad"]
    X = torch.cat(X)
    y = torch.cat(y)
    y_pad = torch.cat(y_pad)
    y_step = y-y_pad # prev_pad + step
    dataset = AnDiDataset(X, y_step)

    # ## split
    train_set, val_set = torch.utils.data.random_split(dataset, [0.7, 0.3], generator=g)
    
    train_loader = DataLoader(train_set, batch_size=256, collate_fn=collate_fn, generator=g, shuffle=True)
    
    valid_loader = DataLoader(val_set, batch_size=64, collate_fn=collate_fn, generator=g, shuffle=True)

    train_dataloader_dict[f"{feat}"] = train_loader
    valid_dataloader_dict[f"{feat}"] = valid_loader

del X, y, y_pad
import gc
gc.collect()
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
# 33

# %%
feat = "cp"

model_name=f'predictor_{feat}_step_full_{dataset_size}'


model = resnet18_andi(output_dim=1, output_num=1, problem_type="cp")
criterion = nn.L1Loss()

train_dataloader = train_dataloader_dict["cp"]
valid_dataloader = valid_dataloader_dict["cp"]

model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
                                                  criterion, 
                                                  # optimizer=optimizer, scheduler=scheduler,
                                                  num_epochs=num_epochs, device=device,  model_name=model_name,
                                                  tag=f"{feat}")
if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
    total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
else:
    np.save(f"./model/loss/{model_name}_{feat}.npy", np.array([total_train_loss, total_valid_loss]))

print(np.argmin(total_valid_loss), np.min(total_valid_loss))


plt.plot(total_train_loss)
plt.plot(total_valid_loss)
plt.title(f"{feat}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       9 train_dataloader = train_dataloader_dict["cp"]
#      10 valid_dataloader = valid_dataloader_dict["cp"]
# ---> 12 model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
#      13                                                   criterion,
#      14                                                   # optimizer=optimizer, scheduler=scheduler,
#      15                                                   num_epochs=num_epochs, device=device,  model_name=model_name,
#      16                                                   tag=f"{feat}")
#      17 if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
#      18     total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
#
# File ~/AnDi2/utils/train.py:31, in train(model, train_dataloader, valid_dataloader, criterion, num_epochs, clf, optimizer, scheduler, device, model_name, tag)
#      28 total_valid_loss = []
#      30 model.to(device)
# ---> 31 createFolder(f'./model/{model_name}')
#      33 for epoch in range(num_epochs):
#      34     train_loss = []
#
# NameError: name 'createFolder' is not defined

# %%
# CP clf

# %%
X_dict = {f"{feat}":[] for feat in ["feat"]}
y_dict = {f"{feat}":[] for feat in ["cp"]}

for i in tqdm(range(dataset_size)):

    X = np.load(f"./ds_single/ds_{i}.npy", allow_pickle=True)
    y = np.load(f"./ds_single/ds_label_{i}.npy", allow_pickle=True)

    ### TO Tensor
    X = torch.Tensor(X).squeeze().unsqueeze(axis=2).type(torch.Tensor)
    
    y_cp = torch.Tensor(y[:,4])
    y_cp_clf = torch.where(y_cp<200, 1, 0) #cp exist = True, else False
    # print(y_cp, y_cp_clf)
    X_dict["feat"].append(X)
    y_dict["cp"].append(y_cp_clf)

train_dataloader_dict = {f"{feat}":[] for feat in ["cp"]}
valid_dataloader_dict = {f"{feat}":[] for feat in ["cp"]}

g = torch.Generator()
g.manual_seed(42)

for feat in ["cp"]:
    X = X_dict["feat"]
    y = y_dict[feat]
    X = torch.cat(X)
    y = torch.cat(y)
    y = y.type(torch.long)
    dataset = AnDiDataset(X, y)

    # ## split
    train_set, val_set = torch.utils.data.random_split(dataset, [0.7, 0.3], generator=g)
    
    train_loader = DataLoader(train_set, batch_size=256, collate_fn=collate_fn, generator=g, shuffle=True)
    
    valid_loader = DataLoader(val_set, batch_size=64, collate_fn=collate_fn, generator=g, shuffle=True)

    train_dataloader_dict[f"{feat}"] = train_loader
    valid_dataloader_dict[f"{feat}"] = valid_loader

del X, y
import gc
gc.collect()
# Out:
# 100%|██████████| 200/200 [04:19<00:00,  1.30s/it]
# 572

# %%
feat = "cp"

model_name=f'classifier_{feat}_full_{dataset_size}'
# resnet34 / Scheduler / CrossEntropyLoss ~ 95%

# model = resnet34_andi(output_dim=2, output_num=1, problem_type="s")
model = resnet18_andi(output_dim=2, output_num=1, problem_type="s")

criterion = nn.CrossEntropyLoss()


train_dataloader = train_dataloader_dict["cp"]
valid_dataloader = valid_dataloader_dict["cp"]


model, total_train_loss, total_valid_loss = train(model, train_dataloader, valid_dataloader,
                                                  criterion, clf=True,
                                                  # optimizer=optimizer, scheduler=scheduler,
                                                  num_epochs=num_epochs, device=device,  model_name=model_name,
                                                  tag=f"{feat}")
if os.path.exists(f"./model/loss/{model_name}_{feat}.npy") and total_train_loss is None:
    total_train_loss, total_valid_loss = np.load(f"./model/loss/{model_name}_{feat}.npy")
else:
    np.save(f"./model/loss/{model_name}_{feat}.npy", np.array([total_train_loss, total_valid_loss]))

print(np.argmin(total_valid_loss), np.min(total_valid_loss))


plt.plot(total_train_loss)
plt.plot(total_valid_loss)
plt.title(f"{feat}")
plt.show()
# Out:
# Epoch 0 Loss:  0.6293121601463537
# Epoch 0 Eval ACC:  0.6540361448178862
# Epoch 0 Eval Loss:  0.608629336788098
# [EarlyStopping] (Update) Best Score: 0.60863
# Epoch 1 Loss:  0.17248737089974892
# Epoch 1 Eval ACC:  0.9488779145786043
# Epoch 1 Eval Loss:  0.14644684134628874
# [EarlyStopping] (Update) Best Score: 0.14645
# Epoch 2 Loss:  0.148674096222966
# Epoch 2 Eval ACC:  0.9511308346254611
# Epoch 2 Eval Loss:  0.14102036551549613
# [EarlyStopping] (Update) Best Score: 0.14102
# Epoch 3 Loss:  0.141510215888211
# Epoch 3 Eval ACC:  0.9484963520679716
# Epoch 3 Eval Loss:  0.14666192710558287
# [EarlyStopping] (Patience) 1/10, Best: 0.14102, Current: 0.14666, Delta: 0.00564
# Epoch 4 Loss:  0.13724714723633885
# Epoch 4 Eval ACC:  0.9508931037271168
# Epoch 4 Eval Loss:  0.14011177444667952
# [EarlyStopping] (Update) Best Score: 0.14011
# Epoch 5 Loss:  0.1342326254012875
# Epoch 5 Eval ACC:  0.9537363741088958
# Epoch 5 Eval Loss:  0.1336557933284066
# [EarlyStopping] (Update) Best Score: 0.13366
# Epoch 6 Loss:  0.1319985930710047
# Epoch 6 Eval ACC:  0.9549908685706054
# Epoch 6 Eval Loss:  0.13224657254645936
# [EarlyStopping] (Update) Best Score: 0.13225
# Epoch 7 Loss:  0.1300609672539875
# Epoch 7 Eval ACC:  0.9550089856093268
# Epoch 7 Eval Loss:  0.12971024644848445
# [EarlyStopping] (Update) Best Score: 0.12971
# Epoch 8 Loss:  0.1284848896402519
# Epoch 8 Eval ACC:  0.9558852316528528
# Epoch 8 Eval Loss:  0.12819758804916104
# [EarlyStopping] (Update) Best Score: 0.12820
# Epoch 9 Loss:  0.12688190721494813
# Epoch 9 Eval ACC:  0.9551369095778598
# Epoch 9 Eval Loss:  0.1291265181017128
# [EarlyStopping] (Patience) 1/10, Best: 0.12820, Current: 0.12913, Delta: 0.00093
# Epoch 10 Loss:  0.12540086384774346
# Epoch 10 Eval ACC:  0.9532478768819074
# Epoch 10 Eval Loss:  0.13592963115931245
# [EarlyStopping] (Patience) 2/10, Best: 0.12820, Current: 0.13593, Delta: 0.00773
# Epoch 11 Loss:  0.123984035010058
# Epoch 11 Eval ACC:  0.9491746363225416
# Epoch 11 Eval Loss:  0.14441289779591748
# [EarlyStopping] (Patience) 3/10, Best: 0.12820, Current: 0.14441, Delta: 0.01622
# Epoch 12 Loss:  0.12246408005693692
# Epoch 12 Eval ACC:  0.9575822679262574
# Epoch 12 Eval Loss:  0.12367081768154196
# [EarlyStopping] (Update) Best Score: 0.12367
# Epoch 13 Loss:  0.12091314847418862
# Epoch 13 Eval ACC:  0.9565758885192326
# Epoch 13 Eval Loss:  0.1272829032007033
# [EarlyStopping] (Patience) 1/10, Best: 0.12367, Current: 0.12728, Delta: 0.00361
# Epoch 14 Loss:  0.11934944726696503
# Epoch 14 Eval ACC:  0.9565948893159404
# Epoch 14 Eval Loss:  0.1257834602821987
# [EarlyStopping] (Patience) 2/10, Best: 0.12367, Current: 0.12578, Delta: 0.00211
# Epoch 15 Loss:  0.11770425189000938
# Epoch 15 Eval ACC:  0.9571973913231757
# Epoch 15 Eval Loss:  0.12448194945742484
# [EarlyStopping] (Patience) 3/10, Best: 0.12367, Current: 0.12448, Delta: 0.00081
# Epoch 16 Loss:  0.11585970862030423
# Epoch 16 Eval ACC:  0.9577329486629405
# Epoch 16 Eval Loss:  0.12325375971224778
# [EarlyStopping] (Update) Best Score: 0.12325
# Epoch 17 Loss:  0.11411442259710268
# Epoch 17 Eval ACC:  0.9584724331580694
# Epoch 17 Eval Loss:  0.12114480378196865
# [EarlyStopping] (Update) Best Score: 0.12114
# Epoch 18 Loss:  0.11220540167362801
# Epoch 18 Eval ACC:  0.9579996226353398
# Epoch 18 Eval Loss:  0.12240742423684411
# [EarlyStopping] (Patience) 1/10, Best: 0.12114, Current: 0.12241, Delta: 0.00126
# Epoch 19 Loss:  0.11041905460049789
# Epoch 19 Eval ACC:  0.9588316807795453
# Epoch 19 Eval Loss:  0.12069603947138796
# [EarlyStopping] (Update) Best Score: 0.12070
# Epoch 20 Loss:  0.10496537727238109
# Epoch 20 Eval ACC:  0.9596222022983893
# Epoch 20 Eval Loss:  0.1185090939378343
# [EarlyStopping] (Update) Best Score: 0.11851
# Epoch 21 Loss:  0.09571830654234083
# Epoch 21 Eval ACC:  0.9628631637740531
# Epoch 21 Eval Loss:  0.11236089916265425
# [EarlyStopping] (Update) Best Score: 0.11236
# Epoch 22 Loss:  0.09169368503833157
# Epoch 22 Eval ACC:  0.9633364161757759
# Epoch 22 Eval Loss:  0.11165203455740712
# [EarlyStopping] (Update) Best Score: 0.11165
# Epoch 23 Loss:  0.08926230830873162
# Epoch 23 Eval ACC:  0.963661639114775
# Epoch 23 Eval Loss:  0.11154048992986455
# [EarlyStopping] (Update) Best Score: 0.11154
# Epoch 24 Loss:  0.08729998494169329
# Epoch 24 Eval ACC:  0.9639643262251205
# Epoch 24 Eval Loss:  0.11157016661720434
# [EarlyStopping] (Patience) 1/10, Best: 0.11154, Current: 0.11157, Delta: 0.00003
# Epoch 25 Loss:  0.08543372842146715
# Epoch 25 Eval ACC:  0.9642986076834803
# Epoch 25 Eval Loss:  0.1123770414195462
# [EarlyStopping] (Patience) 2/10, Best: 0.11154, Current: 0.11238, Delta: 0.00084
# Epoch 26 Loss:  0.08365118094185046
# Epoch 26 Eval ACC:  0.9638726363340304
# Epoch 26 Eval Loss:  0.11339766102387748
# [EarlyStopping] (Patience) 3/10, Best: 0.11154, Current: 0.11340, Delta: 0.00186
# Epoch 27 Loss:  0.08191817140391541
# Epoch 27 Eval ACC:  0.9644607772739866
# Epoch 27 Eval Loss:  0.1127344797716992
# [EarlyStopping] (Patience) 4/10, Best: 0.11154, Current: 0.11273, Delta: 0.00119
# Epoch 28 Loss:  0.08026228151302896
# Epoch 28 Eval ACC:  0.9648708409796811
# Epoch 28 Eval Loss:  0.11228643394010555
# [EarlyStopping] (Patience) 5/10, Best: 0.11154, Current: 0.11229, Delta: 0.00075
# Epoch 29 Loss:  0.07882078456257913
# Epoch 29 Eval ACC:  0.9650705702846099
# Epoch 29 Eval Loss:  0.11254030829559027
# [EarlyStopping] (Patience) 6/10, Best: 0.11154, Current: 0.11254, Delta: 0.00100
# Epoch 30 Loss:  0.0775097382057861
# Epoch 30 Eval ACC:  0.9652420193339735
# Epoch 30 Eval Loss:  0.11099947256358439
# [EarlyStopping] (Update) Best Score: 0.11100
# Epoch 31 Loss:  0.07632285401292997
# Epoch 31 Eval ACC:  0.9647228115169574
# Epoch 31 Eval Loss:  0.11286065302454404
# [EarlyStopping] (Patience) 1/10, Best: 0.11100, Current: 0.11286, Delta: 0.00186
# Epoch 32 Loss:  0.07542157742662275
# Epoch 32 Eval ACC:  0.9651790515774418
# Epoch 32 Eval Loss:  0.1135264492431701
# [EarlyStopping] (Patience) 2/10, Best: 0.11100, Current: 0.11353, Delta: 0.00253
# Epoch 33 Loss:  0.07450089064753294
# Epoch 33 Eval ACC:  0.9642305583185267
# Epoch 33 Eval Loss:  0.11571368873937542
# [EarlyStopping] (Patience) 3/10, Best: 0.11100, Current: 0.11571, Delta: 0.00471
# Epoch 34 Loss:  0.07390697621392063
# Epoch 34 Eval ACC:  0.9652806837458789
# Epoch 34 Eval Loss:  0.11347298449295624
# [EarlyStopping] (Patience) 4/10, Best: 0.11100, Current: 0.11347, Delta: 0.00247
# Epoch 35 Loss:  0.0734266671284814
# Epoch 35 Eval ACC:  0.9645615256844374
# Epoch 35 Eval Loss:  0.11520163628720496
# [EarlyStopping] (Patience) 5/10, Best: 0.11100, Current: 0.11520, Delta: 0.00420
# Epoch 36 Loss:  0.07299711648126467
# Epoch 36 Eval ACC:  0.9644212291040948
# Epoch 36 Eval Loss:  0.11390861103346236
# [EarlyStopping] (Patience) 6/10, Best: 0.11100, Current: 0.11391, Delta: 0.00291
# Epoch 37 Loss:  0.07270717550080472
# Epoch 37 Eval ACC:  0.9648688525242116
# Epoch 37 Eval Loss:  0.11507391747310007
# [EarlyStopping] (Patience) 7/10, Best: 0.11100, Current: 0.11507, Delta: 0.00407
# Epoch 38 Loss:  0.0725416754478838
# Epoch 38 Eval ACC:  0.9653891650387109
# Epoch 38 Eval Loss:  0.11433808871833588
# [EarlyStopping] (Patience) 8/10, Best: 0.11100, Current: 0.11434, Delta: 0.00334
# Epoch 39 Loss:  0.07235644647823863
# Epoch 39 Eval ACC:  0.9651251423402707
# Epoch 39 Eval Loss:  0.1137560617830977
# [EarlyStopping] (Patience) 9/10, Best: 0.11100, Current: 0.11376, Delta: 0.00276
# Epoch 40 Loss:  0.06636752243025387
# Epoch 40 Eval ACC:  0.9654673776205082
# Epoch 40 Eval Loss:  0.11312314584893195
# [EarlyStopping] (Patience) 10/10, Best: 0.11100, Current: 0.11312, Delta: 0.00212
# [EarlyStop Triggered] Best Score: 0.11100
# 30 0.11099947256358439
